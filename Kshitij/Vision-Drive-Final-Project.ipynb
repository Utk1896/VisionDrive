# %% [markdown]
# # Problem Statement (Final model)
#
# * The objective of this project is to design and implement a vision-based Advanced Driver Assistance System (ADAS) using a front-facing driving video. The system must operate on continuous video input and perform the following tasks in real time:\
#
# * Lane Detection and Lane Area Estimation\
# The system shall detect left and right road lane boundaries using classical image processing techniques. Based on the detected lanes, the drivable lane area and lane center must be estimated and visualized on the video frames.
#
# * Vehicle Detection using YOLO\
# The system shall detect road vehicles such as cars and trucks using a pretrained YOLO object detection model. For each detected vehicle, a bounding box and confidence score must be displayed on the frame.
#
# * Masked Region of Interest (ROI) Processing\
# A fixed road-facing Region of Interest (ROI) must be defined ahead of the vehicle. Binary masking shall be applied to isolate this region, and only vehicles entering this masked region shall be considered for further safety and traffic analysis.
#
# * Vehicle Counting within ROI\
# The system shall count the total number of unique vehicles that enter the masked ROI during the video. Each vehicle must be counted only once, based on its spatial entry into the region.
#
# * Forward Collision Risk Estimation\
# The system shall estimate collision risk using the relative position and size of detected vehicle bounding boxes within the ROI. Vehicles closer to the bottom of the frame or exceeding a predefined size threshold shall trigger appropriate safety warnings.
#
# * Lane Departure Warning\
# The system shall monitor the vehicle’s position relative to the estimated lane center. If the deviation exceeds a defined threshold, a lane departure warning must be generated.
#
# * Unified ADAS Visualization\
# All outputs including lane overlays, detected vehicles, ROI mask, vehicle count, and warning messages must be displayed together on a single annotated video stream.

# %%
# !pip install ultralytics opencv-python
import cv2
import numpy as np
from ultralytics import YOLO
# pip installing and importing all required libraries
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.252)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
# Load YOLO model
model = YOLO("yolov8n.pt")

# Load video
video_path = "/content/01095.mp4"
cap = cv2.VideoCapture(video_path)

width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))  # Frame Width
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) #  Frame Height
fps    = int(cap.get(cv2.CAP_PROP_FPS))          # Frames per second
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 72.2MB/s 0.1s

# %% [markdown]
# # ROI Mask

# %%
def create_roi_mask(frame):

    mask = np.zeros((height, width), dtype=np.uint8) # Initialize the mask

    # Create a polygonal mask( Trapezoid )
    points = np.array([
        [width*0.1, height],
        [width*0.45, height*0.6],
        [width*0.55, height*0.6],
        [width*0.9, height]
    ], dtype=np.int32)

    cv2.fillPoly(mask, [points], 255)
    return mask, points

# %% [markdown]
# # Lane Detection

# %%
def detect_lanes(frame, mask):

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) # Grayscale version of the video frame

    blur = cv2.GaussianBlur(gray, (5,5), 0) # Blurring the frame

    edges = cv2.Canny(blur, 50, 150) # Applying edge detection

    masked = cv2.bitwise_and(edges, mask) # Apply the mask over edges

    lines = cv2.HoughLinesP(masked, 1, np.pi/180, 100, minLineLength=50, maxLineGap=150) # Line Detection

    left = []
    right = []

    if lines is not None:
        for line in lines:
            x1,y1,x2,y2 = line[0]
            slope = (y2-y1)/(x2-x1+1e-15) # Add 0.001 to avoid division by zero

            # Distinguishing into right and left lanes based on slope (a certain threshold)
            if slope < -0.5:
                left.append(line[0])
            elif slope > 0.5:
                right.append(line[0])

    return left, right

# %% [markdown]
# # Lane Area and Lane Center
#
# We need this function because we need to decide the extent(spread) of the lane about the center of the lane

# %%
def draw_lanes(frame, left, right):

    if len(left) == 0 or len(right) == 0:
        return None, None, None # Return None for all three values if no lanes

    left_avg = np.mean(left, axis=0).astype(int)
    right_avg = np.mean(right, axis=0).astype(int)

    # Polygonal Region(Quadilateral)
    # Bottom Left, Top Left, Bottom Right , Top Right point coordinates
    lane_area = np.array([
        [left_avg[0], left_avg[1]],
        [left_avg[2], left_avg[3]],
        [right_avg[2], right_avg[3]],
        [right_avg[0], right_avg[1]]
    ])

    # Polygonal shape
    overlay = frame.copy()
    cv2.fillPoly(overlay, [lane_area], (0,255,0))

    # Brightness and Contrastness adjustment
    cv2.addWeighted(overlay, 0.3, frame, 0.7, 0, frame)

    """ Ceneter of lane(only Y needed as X coordinate is zero as refernce is the
     line parallel to lanes )"""

    lane_center = (left_avg[2] + right_avg[2]) // 2

    return left_avg, right_avg, lane_center

# %% [markdown]
# # Vehicle Detection Function

# %%
def detect_vehicles(frame):
    results = model(frame)[0]
    vehicles = []

    for box in results.boxes:
        cls = int(box.cls[0])
        label = model.names[cls]

        # Creating labels for objects like car,bus,etc.
        if label in ["car", "truck", "bus", "motorcycle"]:

            # Conversion to intger type list from tensor
            x1,y1,x2,y2 = box.xyxy[0].int().tolist()

            conf = float(box.conf[0]) # Confidence score

            vehicles.append((x1,y1,x2,y2,conf,label)) # Add vehicles' attributes to the list

    return vehicles

# %% [markdown]
# # Count Vehicles

# %%
vehicle_count = 0
counted_points = []

def count_vehicles(vehicles, mask):
    global vehicle_count

    for v in vehicles:
        x1,y1,x2,y2,_,_ = v # We do not require label and confidence scores of vehicles

        # Center
        cx = (x1 + x2) // 2
        cy = (y1 + y2) // 2


        if mask[cy, cx] == 255:
            point = (cx//20, cy//20)

            if point not in counted_points:

              #Ensuring vehicles are being counted only once
                counted_points.append(point)
                vehicle_count += 1

# %% [markdown]
# # Lane Departutre

# %%
def check_lane_departure(left_lane_avg, right_lane_avg, frame_width):

    # If either averaged lane is None (meaning no lines were detected and averaged)
    if left_lane_avg is None or right_lane_avg is None:
        return 'unknown', 0, None, None

    vehicle_center = frame_width // 2

    # Extract x-coordinates from the averaged lines. These are already single arrays.
    # Based on draw_lanes, the 'lane_center' is derived from left_avg[2] and right_avg[2],
    # which correspond to the x2 (bottom x) coordinate of the averaged line segments.
    left_x = left_lane_avg[2]
    right_x = right_lane_avg[2]

    lane_center = (left_x + right_x) // 2
    deviation = abs(vehicle_center - lane_center)


    # Check for Left and Right Direction

    if vehicle_center < lane_center:
        direction = 'left'
    else:
        direction = 'right'

    warning_threshold = frame_width * 0.15
    critical_threshold = frame_width * 0.20

    if deviation >= critical_threshold:
        message = f"LANE DEPARTURE! DRIFTING {direction.upper()}"
        return 'critical', deviation, direction, message

    elif deviation >= warning_threshold:
        message = f"Lane Departure: Drifting {direction}"
        return 'warning', deviation, direction, message

    else:
        return 'safe', deviation, direction, None

# %% [markdown]
# # Check Collision

# %%
def assess_collision_risk(vehicles, frame_height):

    for v in vehicles:

        x1,y1,x2,y2,_,_ = v # We do not need confidence score and label here
        box_height = y2 - y1

  # Criteria for Collision (ratio factors for collisions ) seems to be optimal

        bottom_y = y2
        area = (x2 - x1) * (y2 - y1)

        critical_y = frame_height * 0.85
        warning_y = frame_height * 0.80
        critical_area = (frame_height * 1280) * 0.20
        warning_area = (frame_height * 1280) * 0.15

        if bottom_y >= critical_y or area >= critical_area:
          # Display if satisy above condition
            return 'critical', [{'vehicle': v, 'risk': 'critical'}]

        elif bottom_y >= warning_y or area >= warning_area:
            return 'warning', [{'vehicle': v, 'risk': 'warning'}]

    return 'safe', []

# %% [markdown]
# # Output

# %%
import time

# Video Writer
out = cv2.VideoWriter(
    "ADAS_Output.avi",
    cv2.VideoWriter_fourcc(*"XVID"),
    fps,
    (width, height)
)

frame_count = 0

while True:

    start_time = time.time()

    # Read frame
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1
    height, width = frame.shape[:2]

    # ROI and points in ROI
    mask, roi_points = create_roi_mask(frame)

    # Left, Right and Center of the lane
    left, right = detect_lanes(frame, mask)
    # Unpack the averaged left and right lines along with the lane center
    left_avg_line, right_avg_line, lane_center = draw_lanes(frame, left, right)

    # Detecting and Counting Vehicles
    vehicles = detect_vehicles(frame)
    count_vehicles(vehicles, mask)
    vehicle_count = len(vehicles)

    # Collision Risk
    collision_status, risky_vehicles = assess_collision_risk(vehicles, height)

    # Lane Departure
    # Pass the averaged lane lines to check_lane_departure
    lane_status, deviation, direction, lane_message = check_lane_departure(left_avg_line, right_avg_line, width)

    # Draw ROI
    cv2.polylines(frame, [roi_points], True, (255,0,0), 2)

    # Draw Vehicles
    for v in vehicles:

        x1, y1, x2, y2, conf, label = v

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)

        text = f"{label}: {conf:.2f}"

        (tw, th), _ = cv2.getTextSize(
            text, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1
        )

        cv2.rectangle(
            frame,
            (x1, y1 - th - 6),
            (x1 + tw + 4, y1),
            (0, 0, 255),
            -1
        )

        cv2.putText(
            frame,
            text,
            (x1 + 2, y1 - 4),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (255, 255, 255),
            1
        )

    # FPS
    fps_display = 1.0 / (time.time() - start_time)

    # Annotate
    cv2.putText(frame, f"FPS: {fps_display:.2f}", (20, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,0), 2)

    cv2.putText(frame, f"Width: {width}", (20, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,0), 2)

    cv2.putText(frame, f"Height: {height}", (20, 100),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,0), 2)

    cv2.putText(frame, f"Frame: {frame_count}", (20, 130),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,0), 2)

    cv2.putText(frame, f"Vehicles: {vehicle_count}", (20, 160),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,0), 2)



    # Collision warning
    if collision_status == 'critical':
        cv2.putText(frame, "COLLISION WARNING!",
                    (width//3, 80), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0,0,255), 3)

    elif collision_status == 'warning':
        cv2.putText(frame, "CAUTION: Vehicle Close",
                    (width//3, 80), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0,165,255), 3)

    # Lane departure warning with drifting direction
    if lane_status == 'critical' and lane_message is not None:
        cv2.putText(frame, lane_message,
                    (width//3, 120), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0,0,255), 3)

    elif lane_status == 'warning' and lane_message is not None:
        cv2.putText(frame, lane_message,
                    (width//3, 120), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0,255,255), 3)

    # Write frame to output video
    out.write(frame)

# Save the video
cap.release()
out.release()
print("Video saved successfully")
# Out:
# 0: 384x640 1 car, 1 truck, 137.1ms
# Speed: 2.5ms preprocess, 137.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 171.8ms
# Speed: 2.2ms preprocess, 171.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 184.4ms
# Speed: 2.0ms preprocess, 184.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 127.8ms
# Speed: 1.9ms preprocess, 127.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 224.2ms
# Speed: 4.4ms preprocess, 224.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 269.4ms
# Speed: 1.8ms preprocess, 269.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 147.9ms
# Speed: 1.8ms preprocess, 147.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 134.1ms
# Speed: 2.9ms preprocess, 134.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 181.9ms
# Speed: 1.9ms preprocess, 181.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 157.9ms
# Speed: 4.6ms preprocess, 157.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 180.8ms
# Speed: 1.8ms preprocess, 180.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 199.7ms
# Speed: 1.9ms preprocess, 199.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 154.4ms
# Speed: 6.5ms preprocess, 154.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 186.0ms
# Speed: 6.1ms preprocess, 186.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 166.8ms
# Speed: 3.5ms preprocess, 166.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 stop sign, 160.4ms
# Speed: 4.1ms preprocess, 160.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 192.3ms
# Speed: 2.1ms preprocess, 192.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 2 trucks, 210.7ms
# Speed: 2.0ms preprocess, 210.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 2 trucks, 170.1ms
# Speed: 1.9ms preprocess, 170.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 truck, 173.1ms
# Speed: 4.4ms preprocess, 173.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 211.8ms
# Speed: 3.1ms preprocess, 211.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 174.3ms
# Speed: 2.7ms preprocess, 174.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 218.2ms
# Speed: 6.0ms preprocess, 218.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 205.0ms
# Speed: 5.1ms preprocess, 205.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 2 stop signs, 193.4ms
# Speed: 3.5ms preprocess, 193.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 1 stop sign, 178.7ms
# Speed: 4.3ms preprocess, 178.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 173.1ms
# Speed: 8.5ms preprocess, 173.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 318.4ms
# Speed: 4.5ms preprocess, 318.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 222.1ms
# Speed: 4.9ms preprocess, 222.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 225.2ms
# Speed: 4.3ms preprocess, 225.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 112.6ms
# Speed: 2.0ms preprocess, 112.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 101.4ms
# Speed: 3.4ms preprocess, 101.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 99.1ms
# Speed: 2.0ms preprocess, 99.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 1 stop sign, 140.4ms
# Speed: 2.2ms preprocess, 140.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 1 stop sign, 112.1ms
# Speed: 2.1ms preprocess, 112.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 102.8ms
# Speed: 1.9ms preprocess, 102.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 106.9ms
# Speed: 1.9ms preprocess, 106.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 101.6ms
# Speed: 1.9ms preprocess, 101.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 100.8ms
# Speed: 1.8ms preprocess, 100.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 109.4ms
# Speed: 2.0ms preprocess, 109.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 109.5ms
# Speed: 2.5ms preprocess, 109.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 118.8ms
# Speed: 3.0ms preprocess, 118.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 121.4ms
# Speed: 2.7ms preprocess, 121.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 stop sign, 115.9ms
# Speed: 5.0ms preprocess, 115.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 stop sign, 109.4ms
# Speed: 2.3ms preprocess, 109.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 119.2ms
# Speed: 3.8ms preprocess, 119.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 110.0ms
# Speed: 2.6ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 113.1ms
# Speed: 3.8ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 116.6ms
# Speed: 2.7ms preprocess, 116.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 130.7ms
# Speed: 3.2ms preprocess, 130.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 125.0ms
# Speed: 3.4ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 115.0ms
# Speed: 2.4ms preprocess, 115.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 109.3ms
# Speed: 2.3ms preprocess, 109.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 118.2ms
# Speed: 2.4ms preprocess, 118.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.9ms
# Speed: 3.6ms preprocess, 98.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 truck, 105.4ms
# Speed: 1.8ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 104.1ms
# Speed: 1.9ms preprocess, 104.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.5ms
# Speed: 1.6ms preprocess, 97.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.5ms
# Speed: 1.8ms preprocess, 101.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 107.2ms
# Speed: 1.6ms preprocess, 107.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.7ms
# Speed: 2.0ms preprocess, 97.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.1ms
# Speed: 1.8ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 111.4ms
# Speed: 1.9ms preprocess, 111.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 109.3ms
# Speed: 2.0ms preprocess, 109.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 114.3ms
# Speed: 2.1ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 108.1ms
# Speed: 2.4ms preprocess, 108.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 149.0ms
# Speed: 3.4ms preprocess, 149.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 137.3ms
# Speed: 2.6ms preprocess, 137.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 142.2ms
# Speed: 2.0ms preprocess, 142.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 131.4ms
# Speed: 2.1ms preprocess, 131.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 123.7ms
# Speed: 1.8ms preprocess, 123.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 131.9ms
# Speed: 1.9ms preprocess, 131.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 136.4ms
# Speed: 2.8ms preprocess, 136.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 165.3ms
# Speed: 5.0ms preprocess, 165.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 106.0ms
# Speed: 1.8ms preprocess, 106.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 99.7ms
# Speed: 2.9ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.6ms
# Speed: 2.1ms preprocess, 97.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 96.2ms
# Speed: 1.9ms preprocess, 96.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.8ms
# Speed: 2.7ms preprocess, 97.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.3ms
# Speed: 1.8ms preprocess, 101.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.9ms
# Speed: 1.6ms preprocess, 98.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.1ms
# Speed: 1.9ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.0ms
# Speed: 1.7ms preprocess, 98.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.5ms
# Speed: 1.6ms preprocess, 97.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 95.6ms
# Speed: 1.7ms preprocess, 95.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 104.5ms
# Speed: 1.8ms preprocess, 104.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 95.4ms
# Speed: 1.7ms preprocess, 95.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.8ms
# Speed: 1.6ms preprocess, 97.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 96.3ms
# Speed: 1.7ms preprocess, 96.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.5ms
# Speed: 1.7ms preprocess, 97.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.7ms
# Speed: 1.8ms preprocess, 98.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.4ms
# Speed: 1.8ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.8ms
# Speed: 2.7ms preprocess, 101.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 107.5ms
# Speed: 2.1ms preprocess, 107.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.7ms
# Speed: 1.6ms preprocess, 99.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 98.4ms
# Speed: 1.9ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.1ms
# Speed: 1.9ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.9ms
# Speed: 2.2ms preprocess, 98.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.8ms
# Speed: 1.8ms preprocess, 101.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 107.2ms
# Speed: 2.1ms preprocess, 107.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 105.7ms
# Speed: 2.3ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 118.0ms
# Speed: 4.7ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 100.2ms
# Speed: 1.9ms preprocess, 100.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 110.1ms
# Speed: 1.8ms preprocess, 110.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 111.3ms
# Speed: 2.2ms preprocess, 111.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 122.3ms
# Speed: 2.3ms preprocess, 122.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 truck, 99.2ms
# Speed: 1.7ms preprocess, 99.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 bench, 101.1ms
# Speed: 1.5ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 96.0ms
# Speed: 1.7ms preprocess, 96.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 103.6ms
# Speed: 1.5ms preprocess, 103.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 100.9ms
# Speed: 1.4ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.3ms
# Speed: 1.8ms preprocess, 98.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 96.2ms
# Speed: 1.6ms preprocess, 96.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 101.0ms
# Speed: 1.8ms preprocess, 101.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 106.7ms
# Speed: 3.6ms preprocess, 106.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 107.6ms
# Speed: 2.4ms preprocess, 107.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 111.4ms
# Speed: 2.1ms preprocess, 111.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 109.5ms
# Speed: 2.4ms preprocess, 109.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 103.8ms
# Speed: 3.6ms preprocess, 103.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 108.3ms
# Speed: 2.7ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 109.1ms
# Speed: 2.8ms preprocess, 109.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 110.9ms
# Speed: 3.3ms preprocess, 110.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 132.8ms
# Speed: 2.3ms preprocess, 132.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 263.6ms
# Speed: 10.8ms preprocess, 263.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 245.9ms
# Speed: 5.8ms preprocess, 245.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 103.8ms
# Speed: 2.7ms preprocess, 103.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 102.8ms
# Speed: 1.8ms preprocess, 102.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 107.2ms
# Speed: 2.3ms preprocess, 107.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.6ms
# Speed: 2.7ms preprocess, 101.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.6ms
# Speed: 1.8ms preprocess, 98.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 96.8ms
# Speed: 1.8ms preprocess, 96.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.0ms
# Speed: 1.9ms preprocess, 97.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 100.1ms
# Speed: 1.6ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.1ms
# Speed: 1.6ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 96.6ms
# Speed: 1.7ms preprocess, 96.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 96.9ms
# Speed: 2.0ms preprocess, 96.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 104.0ms
# Speed: 1.9ms preprocess, 104.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 1 truck, 103.0ms
# Speed: 1.9ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 99.5ms
# Speed: 1.9ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 97.1ms
# Speed: 1.9ms preprocess, 97.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 108.4ms
# Speed: 1.8ms preprocess, 108.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 110.3ms
# Speed: 2.7ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 112.1ms
# Speed: 2.4ms preprocess, 112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 111.9ms
# Speed: 2.4ms preprocess, 111.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 120.8ms
# Speed: 2.5ms preprocess, 120.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 121.1ms
# Speed: 2.4ms preprocess, 121.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 142.9ms
# Speed: 4.2ms preprocess, 142.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 137.0ms
# Speed: 3.1ms preprocess, 137.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 124.1ms
# Speed: 2.0ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 126.9ms
# Speed: 2.4ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 140.3ms
# Speed: 1.9ms preprocess, 140.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 truck, 127.4ms
# Speed: 2.1ms preprocess, 127.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 131.7ms
# Speed: 4.9ms preprocess, 131.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 130.5ms
# Speed: 3.1ms preprocess, 130.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.5ms
# Speed: 2.4ms preprocess, 99.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.3ms
# Speed: 2.2ms preprocess, 99.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 99.7ms
# Speed: 1.7ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 106.7ms
# Speed: 1.7ms preprocess, 106.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 99.6ms
# Speed: 1.9ms preprocess, 99.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 100.9ms
# Speed: 3.3ms preprocess, 100.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 98.0ms
# Speed: 1.7ms preprocess, 98.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 105.4ms
# Speed: 2.0ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 98.2ms
# Speed: 2.3ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 103.9ms
# Speed: 1.9ms preprocess, 103.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 111.1ms
# Speed: 2.0ms preprocess, 111.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 100.4ms
# Speed: 2.8ms preprocess, 100.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 97.4ms
# Speed: 3.5ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 98.9ms
# Speed: 1.8ms preprocess, 98.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 106.3ms
# Speed: 1.3ms preprocess, 106.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 120.0ms
# Speed: 1.8ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 109.9ms
# Speed: 2.0ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 105.2ms
# Speed: 2.0ms preprocess, 105.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 115.1ms
# Speed: 2.6ms preprocess, 115.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 105.1ms
# Speed: 3.0ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 104.8ms
# Speed: 2.0ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 95.3ms
# Speed: 1.5ms preprocess, 95.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 101.0ms
# Speed: 2.4ms preprocess, 101.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 95.2ms
# Speed: 1.6ms preprocess, 95.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 97.7ms
# Speed: 1.7ms preprocess, 97.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 104.7ms
# Speed: 1.6ms preprocess, 104.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 95.7ms
# Speed: 1.6ms preprocess, 95.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 95.3ms
# Speed: 1.6ms preprocess, 95.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 97.4ms
# Speed: 1.6ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 111.6ms
# Speed: 2.0ms preprocess, 111.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 107.2ms
# Speed: 3.3ms preprocess, 107.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 107.3ms
# Speed: 2.3ms preprocess, 107.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 107.8ms
# Speed: 2.3ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 115.3ms
# Speed: 2.3ms preprocess, 115.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 106.5ms
# Speed: 2.3ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 truck, 1 boat, 106.2ms
# Speed: 2.4ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 1 truck, 108.6ms
# Speed: 2.1ms preprocess, 108.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 100.9ms
# Speed: 1.5ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 98.0ms
# Speed: 1.7ms preprocess, 98.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 truck, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.7ms
# Speed: 5.8ms preprocess, 99.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 104.2ms
# Speed: 1.7ms preprocess, 104.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 94.3ms
# Speed: 1.8ms preprocess, 94.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 99.7ms
# Speed: 1.6ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 truck, 103.3ms
# Speed: 1.9ms preprocess, 103.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 108.7ms
# Speed: 1.8ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 102.3ms
# Speed: 2.2ms preprocess, 102.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 truck, 106.5ms
# Speed: 1.9ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 108.9ms
# Speed: 2.0ms preprocess, 108.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 1 fire hydrant, 116.5ms
# Speed: 2.1ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 103.1ms
# Speed: 1.9ms preprocess, 103.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 107.7ms
# Speed: 1.9ms preprocess, 107.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 111.3ms
# Speed: 2.5ms preprocess, 111.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 103.7ms
# Speed: 1.7ms preprocess, 103.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 93.5ms
# Speed: 1.5ms preprocess, 93.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 94.8ms
# Speed: 1.9ms preprocess, 94.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 103.9ms
# Speed: 1.9ms preprocess, 103.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 104.4ms
# Speed: 1.8ms preprocess, 104.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 98.5ms
# Speed: 1.9ms preprocess, 98.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.6ms
# Speed: 1.7ms preprocess, 101.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.1ms
# Speed: 1.9ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 traffic light, 95.0ms
# Speed: 1.8ms preprocess, 95.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 100.4ms
# Speed: 2.9ms preprocess, 100.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 106.9ms
# Speed: 4.5ms preprocess, 106.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 101.6ms
# Speed: 2.1ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 102.4ms
# Speed: 3.5ms preprocess, 102.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 99.3ms
# Speed: 3.0ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 102.9ms
# Speed: 1.9ms preprocess, 102.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 103.1ms
# Speed: 2.5ms preprocess, 103.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 99.1ms
# Speed: 1.7ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 101.1ms
# Speed: 1.8ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 93.5ms
# Speed: 1.8ms preprocess, 93.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 95.5ms
# Speed: 1.9ms preprocess, 95.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 95.0ms
# Speed: 1.7ms preprocess, 95.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 96.1ms
# Speed: 1.8ms preprocess, 96.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 101.5ms
# Speed: 1.9ms preprocess, 101.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 144.3ms
# Speed: 2.1ms preprocess, 144.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 124.5ms
# Speed: 1.9ms preprocess, 124.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 136.5ms
# Speed: 1.9ms preprocess, 136.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 3 trucks, 124.9ms
# Speed: 1.9ms preprocess, 124.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 120.1ms
# Speed: 2.1ms preprocess, 120.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 147.0ms
# Speed: 2.3ms preprocess, 147.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 148.6ms
# Speed: 2.4ms preprocess, 148.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 139.1ms
# Speed: 2.5ms preprocess, 139.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 120.4ms
# Speed: 2.3ms preprocess, 120.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 100.0ms
# Speed: 1.9ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 97.4ms
# Speed: 1.7ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 94.0ms
# Speed: 1.7ms preprocess, 94.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 105.4ms
# Speed: 2.0ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 120.5ms
# Speed: 1.8ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 96.3ms
# Speed: 1.8ms preprocess, 96.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 99.7ms
# Speed: 1.8ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 103.1ms
# Speed: 1.6ms preprocess, 103.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trucks, 99.8ms
# Speed: 1.6ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trucks, 107.5ms
# Speed: 1.5ms preprocess, 107.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 95.1ms
# Speed: 1.6ms preprocess, 95.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 117.0ms
# Speed: 1.5ms preprocess, 117.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trucks, 104.0ms
# Speed: 2.2ms preprocess, 104.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trucks, 97.1ms
# Speed: 2.1ms preprocess, 97.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trucks, 113.4ms
# Speed: 2.2ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 115.1ms
# Speed: 1.9ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 116.3ms
# Speed: 3.7ms preprocess, 116.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 118.1ms
# Speed: 2.3ms preprocess, 118.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 2 trucks, 116.4ms
# Speed: 2.4ms preprocess, 116.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 109.8ms
# Speed: 2.2ms preprocess, 109.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 107.6ms
# Speed: 2.3ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 107.2ms
# Speed: 2.3ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 108.6ms
# Speed: 2.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 1 stop sign, 115.4ms
# Speed: 2.1ms preprocess, 115.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 109.9ms
# Speed: 2.4ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 111.5ms
# Speed: 2.0ms preprocess, 111.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 132.1ms
# Speed: 4.1ms preprocess, 132.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trucks, 113.5ms
# Speed: 2.5ms preprocess, 113.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 112.6ms
# Speed: 2.4ms preprocess, 112.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 111.7ms
# Speed: 2.2ms preprocess, 111.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 1 stop sign, 114.1ms
# Speed: 2.2ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 1 stop sign, 103.7ms
# Speed: 2.0ms preprocess, 103.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 109.5ms
# Speed: 2.0ms preprocess, 109.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 trucks, 1 traffic light, 116.8ms
# Speed: 2.1ms preprocess, 116.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 1 traffic light, 114.1ms
# Speed: 2.2ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 109.7ms
# Speed: 3.6ms preprocess, 109.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 110.2ms
# Speed: 2.2ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 traffic light, 112.5ms
# Speed: 2.4ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 111.7ms
# Speed: 2.2ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 113.0ms
# Speed: 2.5ms preprocess, 113.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 127.9ms
# Speed: 3.9ms preprocess, 127.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 stop sign, 121.0ms
# Speed: 2.4ms preprocess, 121.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 115.7ms
# Speed: 2.4ms preprocess, 115.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 104.0ms
# Speed: 2.7ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 102.8ms
# Speed: 1.8ms preprocess, 102.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 traffic light, 95.4ms
# Speed: 1.6ms preprocess, 95.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 102.2ms
# Speed: 1.7ms preprocess, 102.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 107.2ms
# Speed: 1.7ms preprocess, 107.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 116.9ms
# Speed: 1.8ms preprocess, 116.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 102.8ms
# Speed: 1.6ms preprocess, 102.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 108.9ms
# Speed: 1.7ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 107.7ms
# Speed: 3.4ms preprocess, 107.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 114.1ms
# Speed: 2.4ms preprocess, 114.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 102.2ms
# Speed: 3.9ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 101.6ms
# Speed: 1.8ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 103.8ms
# Speed: 1.9ms preprocess, 103.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 112.6ms
# Speed: 2.2ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 103.2ms
# Speed: 1.9ms preprocess, 103.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 103.1ms
# Speed: 2.3ms preprocess, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 105.5ms
# Speed: 1.7ms preprocess, 105.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 103.8ms
# Speed: 1.6ms preprocess, 103.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 101.0ms
# Speed: 1.8ms preprocess, 101.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.2ms
# Speed: 2.9ms preprocess, 95.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 101.3ms
# Speed: 1.6ms preprocess, 101.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 105.4ms
# Speed: 2.7ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 97.4ms
# Speed: 1.8ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 113.0ms
# Speed: 1.6ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 126.9ms
# Speed: 2.0ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 115.4ms
# Speed: 2.5ms preprocess, 115.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 116.9ms
# Speed: 2.7ms preprocess, 116.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 121.1ms
# Speed: 2.5ms preprocess, 121.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 113.3ms
# Speed: 3.7ms preprocess, 113.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 151.9ms
# Speed: 2.3ms preprocess, 151.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 145.2ms
# Speed: 2.7ms preprocess, 145.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 134.5ms
# Speed: 1.6ms preprocess, 134.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 140.8ms
# Speed: 1.8ms preprocess, 140.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 171.2ms
# Speed: 3.6ms preprocess, 171.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 143.2ms
# Speed: 1.9ms preprocess, 143.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 134.3ms
# Speed: 2.6ms preprocess, 134.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 119.2ms
# Speed: 1.8ms preprocess, 119.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 105.9ms
# Speed: 1.7ms preprocess, 105.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 100.9ms
# Speed: 2.1ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 100.5ms
# Speed: 3.4ms preprocess, 100.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 boats, 108.2ms
# Speed: 2.7ms preprocess, 108.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 boat, 96.7ms
# Speed: 1.8ms preprocess, 96.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 104.7ms
# Speed: 3.0ms preprocess, 104.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 96.8ms
# Speed: 1.8ms preprocess, 96.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 boat, 101.9ms
# Speed: 1.6ms preprocess, 101.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 109.0ms
# Speed: 1.6ms preprocess, 109.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 105.6ms
# Speed: 1.6ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 111.2ms
# Speed: 4.1ms preprocess, 111.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 107.9ms
# Speed: 1.6ms preprocess, 107.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 108.3ms
# Speed: 1.8ms preprocess, 108.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 122.1ms
# Speed: 2.2ms preprocess, 122.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 111.6ms
# Speed: 2.8ms preprocess, 111.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 109.4ms
# Speed: 2.5ms preprocess, 109.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 113.4ms
# Speed: 2.7ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 110.6ms
# Speed: 3.5ms preprocess, 110.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 118.6ms
# Speed: 2.3ms preprocess, 118.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 123.6ms
# Speed: 2.6ms preprocess, 123.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 123.9ms
# Speed: 2.2ms preprocess, 123.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 117.0ms
# Speed: 2.3ms preprocess, 117.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 112.6ms
# Speed: 2.9ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 124.7ms
# Speed: 2.2ms preprocess, 124.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 118.9ms
# Speed: 2.5ms preprocess, 118.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 118.8ms
# Speed: 3.4ms preprocess, 118.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 125.0ms
# Speed: 4.1ms preprocess, 125.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 102.1ms
# Speed: 1.8ms preprocess, 102.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 100.1ms
# Speed: 1.9ms preprocess, 100.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.9ms
# Speed: 1.9ms preprocess, 99.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 104.5ms
# Speed: 1.9ms preprocess, 104.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 2 cars, 1 fire hydrant, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 stop sign, 114.4ms
# Speed: 1.9ms preprocess, 114.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 100.5ms
# Speed: 2.2ms preprocess, 100.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 stop sign, 110.3ms
# Speed: 1.9ms preprocess, 110.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 stop sign, 106.0ms
# Speed: 2.3ms preprocess, 106.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 99.5ms
# Speed: 1.9ms preprocess, 99.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 103.6ms
# Speed: 2.4ms preprocess, 103.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 1 stop sign, 109.5ms
# Speed: 1.9ms preprocess, 109.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 98.2ms
# Speed: 2.2ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 105.9ms
# Speed: 1.6ms preprocess, 105.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 117.3ms
# Speed: 2.2ms preprocess, 117.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 115.0ms
# Speed: 2.6ms preprocess, 115.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 112.6ms
# Speed: 3.9ms preprocess, 112.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 109.2ms
# Speed: 2.7ms preprocess, 109.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 106.6ms
# Speed: 2.4ms preprocess, 106.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 117.9ms
# Speed: 2.4ms preprocess, 117.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 traffic light, 1 fire hydrant, 118.8ms
# Speed: 2.3ms preprocess, 118.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 fire hydrant, 116.8ms
# Speed: 3.1ms preprocess, 116.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 117.0ms
# Speed: 2.7ms preprocess, 117.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 118.4ms
# Speed: 3.0ms preprocess, 118.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 116.1ms
# Speed: 4.6ms preprocess, 116.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 113.4ms
# Speed: 2.7ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 115.0ms
# Speed: 2.5ms preprocess, 115.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 109.1ms
# Speed: 2.3ms preprocess, 109.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 100.5ms
# Speed: 4.0ms preprocess, 100.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 102.7ms
# Speed: 2.3ms preprocess, 102.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 97.1ms
# Speed: 2.7ms preprocess, 97.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 102.2ms
# Speed: 1.7ms preprocess, 102.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 105.7ms
# Speed: 1.5ms preprocess, 105.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 99.9ms
# Speed: 3.5ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 99.8ms
# Speed: 1.7ms preprocess, 99.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 107.9ms
# Speed: 1.4ms preprocess, 107.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 108.8ms
# Speed: 4.5ms preprocess, 108.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 130.2ms
# Speed: 4.0ms preprocess, 130.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 108.0ms
# Speed: 4.7ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 134.5ms
# Speed: 2.2ms preprocess, 134.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 150.5ms
# Speed: 4.0ms preprocess, 150.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 152.6ms
# Speed: 2.2ms preprocess, 152.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 134.5ms
# Speed: 2.1ms preprocess, 134.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 138.8ms
# Speed: 6.0ms preprocess, 138.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 143.3ms
# Speed: 2.4ms preprocess, 143.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 traffic light, 155.8ms
# Speed: 4.6ms preprocess, 155.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 163.9ms
# Speed: 2.9ms preprocess, 163.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 153.6ms
# Speed: 3.7ms preprocess, 153.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 99.8ms
# Speed: 3.3ms preprocess, 99.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 99.5ms
# Speed: 1.9ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 97.1ms
# Speed: 1.9ms preprocess, 97.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 108.5ms
# Speed: 1.8ms preprocess, 108.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 103.9ms
# Speed: 1.9ms preprocess, 103.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 106.4ms
# Speed: 2.1ms preprocess, 106.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 102.8ms
# Speed: 2.4ms preprocess, 102.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 2 trucks, 116.3ms
# Speed: 3.2ms preprocess, 116.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 2 trucks, 100.0ms
# Speed: 2.4ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 2 trucks, 113.6ms
# Speed: 2.4ms preprocess, 113.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 101.9ms
# Speed: 1.8ms preprocess, 101.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 105.2ms
# Speed: 1.9ms preprocess, 105.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 106.7ms
# Speed: 2.3ms preprocess, 106.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 101.0ms
# Speed: 4.4ms preprocess, 101.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 112.7ms
# Speed: 4.4ms preprocess, 112.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 fire hydrant, 109.4ms
# Speed: 2.2ms preprocess, 109.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 100.6ms
# Speed: 1.8ms preprocess, 100.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 103.1ms
# Speed: 1.9ms preprocess, 103.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 105.4ms
# Speed: 1.9ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 103.9ms
# Speed: 1.7ms preprocess, 103.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 103.5ms
# Speed: 1.7ms preprocess, 103.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 airplane, 1 truck, 108.8ms
# Speed: 1.9ms preprocess, 108.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 110.8ms
# Speed: 1.7ms preprocess, 110.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 113.7ms
# Speed: 4.3ms preprocess, 113.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 100.4ms
# Speed: 1.8ms preprocess, 100.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 102.0ms
# Speed: 1.7ms preprocess, 102.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 98.7ms
# Speed: 1.7ms preprocess, 98.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 99.4ms
# Speed: 2.0ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 102.3ms
# Speed: 1.6ms preprocess, 102.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 98.5ms
# Speed: 1.2ms preprocess, 98.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 108.2ms
# Speed: 1.7ms preprocess, 108.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 104.4ms
# Speed: 2.0ms preprocess, 104.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 99.3ms
# Speed: 1.6ms preprocess, 99.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 108.3ms
# Speed: 1.7ms preprocess, 108.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 98.5ms
# Speed: 1.6ms preprocess, 98.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 112.5ms
# Speed: 1.7ms preprocess, 112.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 106.4ms
# Speed: 2.2ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 104.4ms
# Speed: 3.5ms preprocess, 104.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 105.4ms
# Speed: 2.3ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 105.9ms
# Speed: 3.1ms preprocess, 105.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 113.1ms
# Speed: 2.5ms preprocess, 113.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 109.4ms
# Speed: 3.9ms preprocess, 109.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 100.8ms
# Speed: 1.8ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 107.0ms
# Speed: 2.3ms preprocess, 107.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 102.0ms
# Speed: 1.8ms preprocess, 102.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 110.6ms
# Speed: 1.7ms preprocess, 110.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 99.0ms
# Speed: 1.9ms preprocess, 99.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 99.5ms
# Speed: 1.9ms preprocess, 99.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 105.5ms
# Speed: 2.0ms preprocess, 105.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 98.9ms
# Speed: 2.1ms preprocess, 98.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 104.0ms
# Speed: 2.5ms preprocess, 104.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 104.3ms
# Speed: 1.9ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 98.5ms
# Speed: 2.0ms preprocess, 98.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 105.8ms
# Speed: 3.2ms preprocess, 105.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 105.6ms
# Speed: 1.9ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.3ms
# Speed: 1.8ms preprocess, 106.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 101.4ms
# Speed: 2.6ms preprocess, 101.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.6ms
# Speed: 3.2ms preprocess, 98.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 98.2ms
# Speed: 1.7ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 103.2ms
# Speed: 1.9ms preprocess, 103.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 109.7ms
# Speed: 2.1ms preprocess, 109.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 126.4ms
# Speed: 1.8ms preprocess, 126.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 106.5ms
# Speed: 2.0ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 116.8ms
# Speed: 5.1ms preprocess, 116.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 115.5ms
# Speed: 3.9ms preprocess, 115.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 114.4ms
# Speed: 3.2ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 114.7ms
# Speed: 2.2ms preprocess, 114.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 108.8ms
# Speed: 2.0ms preprocess, 108.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 113.8ms
# Speed: 2.3ms preprocess, 113.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 110.5ms
# Speed: 2.5ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 108.0ms
# Speed: 2.4ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 108.9ms
# Speed: 2.3ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 116.5ms
# Speed: 2.8ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 truck, 109.4ms
# Speed: 2.0ms preprocess, 109.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Video saved successfully

# %%
# !ffmpeg -y -i ADAS_Output.avi -vcodec libx264 ADAS_Output.mp4
from IPython.display import Video

Video("ADAS_Output.mp4", embed=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
